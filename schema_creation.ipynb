# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import os

current_directory = os.getcwd()
print("Current working directory:", current_directory)
# Out:
# Current working directory: /home/msds2026/mchavez/dmw1/lab_1_test

# %%
path = "/mnt/data/public/rossmann/rossmann_store_sales.json"

# %%
df = pd.read_json(path)

# %%
sqlite_url = "sqlite:///rossmann.db"

# %%
e = create_engine(sqlite_url, echo=True)
df.to_sql(name='rossmann', con=e)
# Out:
# 2025-10-28 14:12:18,974 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-28 14:12:19,049 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("rossmann")
# 2025-10-28 14:12:19,051 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-28 14:12:19,054 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("rossmann")
# 2025-10-28 14:12:19,055 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-10-28 14:12:19,062 INFO sqlalchemy.engine.Engine
# CREATE TABLE rossmann (
# 	"index" BIGINT,
# 	"Store" BIGINT,
# 	"DayOfWeek" BIGINT,
# 	"Date" DATETIME,
# 	"Sales" BIGINT,
# 	"Customers" BIGINT,
# 	"Open" BIGINT,
# 	"Promo" BIGINT,
# 	"StateHoliday" TEXT,
# 	"SchoolHoliday" BIGINT,
# 	"StoreType" TEXT,
# 	"Assortment" TEXT,
# 	"CompetitionDistance" FLOAT,
# 	"CompetitionOpenSinceMonth" FLOAT,
# 	"CompetitionOpenSinceYear" FLOAT,
# 	"Promo2" BIGINT,
# 	"Promo2SinceWeek" FLOAT,
# 	"Promo2SinceYear" FLOAT,
# 	"PromoInterval" TEXT
# )
#
#
# ...
